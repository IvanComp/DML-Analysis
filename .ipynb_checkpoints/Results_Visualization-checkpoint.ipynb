# %% [markdown]
# # Federated Learning Results Visualization
#
# This notebook reads the CSV logs generated by `flower_baseline.py` and regenerates the accuracy and time comparison plots.

# %%
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt

STRATEGY_DISPLAY_NAMES = {
    "fedavg": "FedAvg",
    "fedavgm": "FedAvgM",
    "fedmedian": "FedMedian",
    "fedadam": "FedAdam",
    "fedprox": "FedProx",
    "fedexp": "FedExp",
    "newagg": "FedNew",
}

MARKER_SIZE = 3

def load_results(csv_dir="csv", pattern="baseline_*.csv"):
    if not os.path.exists(csv_dir):
        print(f"Directory {csv_dir} not found.")
        return {}

    results = {}
    csv_files = sorted(glob.glob(os.path.join(csv_dir, pattern)))

    for file_path in csv_files:
        filename = os.path.basename(file_path)
        try:
            stem = filename[:-4] if filename.lower().endswith(".csv") else filename
            parts = stem.split("_")

            if len(parts) < 5 or parts[0].lower() != "baseline":
                raise ValueError("Unexpected filename format")

            strategy_raw = parts[1]
            model_key = parts[2]
            clients_key = parts[-1]
            dataset_key = "_".join(parts[3:-1])

            df = pd.read_csv(file_path, sep=None, engine="python")
            if "Round" not in df.columns:
                raise ValueError("Missing column 'Round'")

            display_name = STRATEGY_DISPLAY_NAMES.get(strategy_raw, strategy_raw)
            group_key = f"{model_key}_{dataset_key}_{clients_key}"
            results.setdefault(group_key, {})[display_name] = df

        except Exception as e:
            print(f"Skipping file {filename}: {e}")

    return results

def _plot_metric(data_dict, y_col, y_label, marker, filename, output_dir):
    fig, ax = plt.subplots(figsize=(10, 6))

    for strategy, df in data_dict.items():
        if "Round" not in df.columns or y_col not in df.columns:
            continue
        ax.plot(df["Round"], df[y_col], label=strategy, marker=marker, markersize=MARKER_SIZE)

    ax.set_xlabel("Federated Learning Round")
    ax.set_ylabel(y_label)
    ax.legend()

    fig.tight_layout()

    os.makedirs(output_dir, exist_ok=True)
    out_path = os.path.join(output_dir, filename)
    fig.savefig(out_path)
    plt.show()
    print(f"Saved: {out_path}")

def plot_results(group_key, data_dict, output_dir="results"):
    _plot_metric(
        data_dict,
        "Accuracy",
        "Testing Accuracy",
        "o",
        f"accuracy_notebook_{group_key}.pdf",
        output_dir,
    )

    _plot_metric(
        data_dict,
        "Duration_Sec",
        "Round Duration (seconds)",
        "s",
        f"time_notebook_{group_key}.pdf",
        output_dir,
    )

all_results = load_results()

for group_key, strategies in all_results.items():
    plot_results(group_key, strategies)
# Out:
# Saved: results/accuracy_notebook_cnn_cifar10_4Clients.pdf
# Saved: results/time_notebook_cnn_cifar10_4Clients.pdf
